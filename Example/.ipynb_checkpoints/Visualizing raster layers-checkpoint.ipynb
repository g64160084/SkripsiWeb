# %%
import rasterio
from rasterio.plot import show
import matplotlib.pyplot as plt
import numpy as np

# %%
fp = r"D:\FORESTS2020\SHARING\ILKOM\DATA\Helsinki_masked_p188r018_7t20020529_z34__LV-FIN.tif"
raster = rasterio.open(fp)

# %%
raster.count
# Out:
# 7

# %%
show((raster, 4), cmap='Reds')
show((raster, 3), cmap='Greens')
show((raster, 1), cmap='Blues')

# %% [markdown]
# # Histogram of the raster data

# %%
from rasterio.plot import show_hist
show_hist(raster, bins=50, lw=0.0, stacked=False, alpha=0.3, histtype='stepfilled', title="Histogram")
